# %%
class Libro:

  _IVA = 10.0 # Porcentaje de IVA compartido por todos los libros

   

  def __init__(self, autor, titulo, precio_base):

    self._autor = autor

    self._titulo = titulo

    self._precio_base = precio_base

   

  @property

  def autor(self):

    return self._autor

   

  @property

  def titulo(self):

    return self._titulo

   

  @property

  def precio_base(self):

    return self._precio_base

   

  def precio_final(self):

    return self._precio_base + self._precio_base * Libro._IVA / 100

   

  def __str__(self):

    return f"({self._autor}; {self._titulo}; {self._precio_base:.2f}; {Libro._IVA}%; {self.precio_final():.2f})"

   

  def __eq__(self, other):

    return self._autor.lower() == other.autor.lower() and self._titulo.lower() == other.titulo.lower()

   

  @classmethod

  def get_IVA(cls):

    return cls._IVA

   

  @classmethod

  def set_IVA(cls, nuevo_iva):

    cls._IVA = nuevo_iva

Presione Mayús + Tabulación para navegar por el historial de chat.

# %%
class Libro:

  _IVA = 10.0 # Porcentaje de IVA compartido por todos los libros

   

  def __init__(self, autor, titulo, precio_base):

    self._autor = autor

    self._titulo = titulo

    self._precio_base = precio_base

   

  @property

  def autor(self):

    return self._autor

   

  @property

  def titulo(self):

    return self._titulo

   

  @property

  def precio_base(self):

    return self._precio_base

   

  def precio_final(self):

    return self._precio_base + self._precio_base * Libro._IVA / 100

   

  def __str__(self):

    return f"({self._autor}; {self._titulo}; {self._precio_base:.2f}; {Libro._IVA}%; {self.precio_final():.2f})"

   

  def __eq__(self, other):

    return self._autor.lower() == other.autor.lower() and self._titulo.lower() == other.titulo.lower()

   

  @classmethod

  def get_IVA(cls):

    return cls._IVA

   

  @classmethod

  def set_IVA(cls, nuevo_iva):

    cls._IVA = nuevo_iva

Álvarez Lara Mo
